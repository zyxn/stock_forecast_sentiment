# %%
# Modul Dasar
import numpy as np               # Operasi matematika dan array
import pandas as pd              # Struktur data tabular (DataFrame)
import matplotlib.pyplot as plt  # Visualisasi data
import seaborn as sns            # Visualisasi data tambahan

# Statistik dan Machine Learning
from scipy import stats          # Statistikaa
from sklearn import datasets     # Datasets untuk machine learning
from sklearn.model_selection import train_test_split  # Pembagian data train-test
from sklearn.preprocessing import StandardScaler     # Normalisasi data
from sklearn.linear_model import LinearRegression    # Regresi linear
from sklearn.tree import DecisionTreeClassifier      # Klasifikasi menggunakan Decision Tree
from sklearn.cluster import KMeans                    # KMeans clustering

# Evaluasi Model
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report  # Evaluasi performa model

# Visualisasi Machine Learning
from sklearn.tree import plot_tree    # Visualisasi struktur Decision Tree
from sklearn.metrics import roc_curve, auc  # Kurva ROC dan AUC


from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import SimpleRNN
from keras.layers import Dropout
from keras.callbacks import EarlyStopping

# %%
import numpy as np
import tensorflow as tf

# Set seed for numpy
np.random.seed(42)

# Set seed for TensorFlow
tf.random.set_seed(42)

# %%
data = pd.read_csv("../data/external/14tahun.csv")
# data = pd.read_csv("../data/external/5 tahun.csv")
data.head(5)
# Out:
#       Tanggal  Terakhir Pembukaan Tertinggi  Terendah    Vol. Perubahan%
# 0  02/10/2024  7.527,98  7.598,03  7.618,93  7.521,71  23,44B     -1,49%
# 1  01/10/2024  7.642,13  7.551,46  7.642,13  7.547,11  20,70B      1,52%
# 2  30/09/2024  7.527,93  7.674,29  7.679,24  7.527,93  22,22B     -2,20%
# 3  27/09/2024  7.696,92  7.713,80  7.736,92  7.663,48  19,05B     -0,61%
# 4  26/09/2024  7.744,52  7.723,10  7.763,08  7.673,05  20,28B      0,05%

# %%
data.columns
# Out:
# Index(['Tanggal', 'Terakhir', 'Pembukaan', 'Tertinggi', 'Terendah', 'Vol.',
#        'Perubahan%'],
#       dtype='object')

# %%
lengh_data = len(data)
split_ratio = 0.9
lengh_train = round(lengh_data * split_ratio)
lengh_validation = lengh_data - lengh_train

# %%
data = data.drop(["Vol.","Perubahan%"],axis=1)
data['Tanggal'] = pd.to_datetime(data['Tanggal'],dayfirst=True)
data = data.set_index("Tanggal")


def convert_to_float(series):
    return series.str.replace('.', '', regex=False).str.replace(',', '.', regex=False).astype(float)

# Terapkan konversi ke kolom "Terakhir", "Pembukaan", "Tertinggi", dan "Terendah"
data['Terakhir'] = convert_to_float(data['Terakhir'])
data['Pembukaan'] = convert_to_float(data['Pembukaan'])
data['Tertinggi'] = convert_to_float(data['Tertinggi'])
data['Terendah'] = convert_to_float(data['Terendah'])



#hai widha

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3604 entries, 2024-10-02 to 2010-01-04
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Terakhir   3604 non-null   float64
#  1   Pembukaan  3604 non-null   float64
#  2   Tertinggi  3604 non-null   float64
#  3   Terendah   3604 non-null   float64
# dtypes: float64(4)
# memory usage: 140.8 KB

# %%
def time_series_to_supervised(data, n_in=1, n_out=1, dropnan=True, var_names=None):
    """
    Mengubah data time series menjadi data supervised learning.

    Argumen:
    data: DataFrame, dataset time series yang akan diubah.
    n_in: int, jumlah timestep mundur sebagai input (X).
    n_out: int, jumlah timestep maju sebagai output (y).
    dropnan: bool, apakah akan menghapus baris dengan nilai NaN.
    var_names: list of str, nama variabel untuk setiap kolom.

    Returns:
    DataFrame yang sudah diubah menjadi format supervised learning.
    """
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = [], []
    
    # Input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        if var_names is None:
            names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
        else:
            names += [(var_names[j] + '(t-%d)' % i) for j in range(n_vars)]
    
    # Output sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            if var_names is None:
                names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
            else:
                names += [(var_names[j] + '(t)') for j in range(n_vars)]
        else:
            if var_names is None:
                names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
            else:
                names += [(var_names[j] + '(t+%d)' % i) for j in range(n_vars)]
    
    # Concatenate semua kolom
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    
    # Hapus baris dengan nilai NaN
    if dropnan:
        agg.dropna(inplace=True)
    
    return agg

# Contoh penggunaan:
# Misalkan 'data' adalah DataFrame yang berisi data time series
# dengan tiga fitur, dan kita ingin menggunakan 3 timestep mundur sebagai input
# dan 1 timestep maju sebagai output, dan nama variabel untuk setiap fitur adalah
# 'A', 'B', dan 'C'

var_names = data.columns
data_supervised = time_series_to_supervised(data, n_in=10, n_out=5, var_names=var_names)

# %%
train_data = data_supervised[lengh_validation:]
validation_data = data_supervised[:lengh_validation]

# %%
lengh_train
# Out:
# 3244

# %%
train_data
# Out:
#             Terakhir(t-10)  Pembukaan(t-10)  Tertinggi(t-10)  Terendah(t-10)  \
# Tanggal
# 2023-03-09         6708.93          6762.25          6772.60         6704.75
# 2023-03-08         6762.25          6694.02          6776.90         6692.17
# 2023-03-07         6691.61          6612.49          6691.61         6609.22
# 2023-03-06         6612.49          6678.24          6678.24         6587.69
# 2023-03-03         6678.24          6565.73          6683.09         6565.73
# ...                    ...              ...              ...             ...
# 2010-01-14         2619.57          2565.38          2619.98         2565.38
# 2010-01-13         2564.55          2577.91          2594.25         2554.88
# 2010-01-12         2578.41          2597.35          2608.74         2568.95
# 2010-01-11         2597.86          2609.73          2609.73         2575.96
# 2010-01-08         2610.34          2636.96          2636.96         2580.17
#
#             Terakhir(t-9)  Pembukaan(t-9)  Tertinggi(t-9)  Terendah(t-9)  \
# Tanggal
# 2023-03-09        6762.25         6694.02         6776.90        6692.17
# 2023-03-08        6691.61         6612.49         6691.61        6609.22
# 2023-03-07        6612.49         6678.24         6678.24        6587.69
# 2023-03-06        6678.24         6565.73         6683.09        6565.73
# 2023-03-03        6565.73         6628.14         6630.77        6542.79
# ...                   ...             ...             ...            ...
# 2010-01-14        2564.55         2577.91         2594.25        2554.88
# 2010-01-13        2578.41         2597.35         2608.74        2568.95
# 2010-01-12        2597.86         2609.73         2609.73        2575.96
# 2010-01-11        2610.34         2636.96         2636.96        2580.17
# 2010-01-08        2638.38         2664.66         2664.66        2621.36
#
#             Terakhir(t-8)  Pembukaan(t-8)  ...  Tertinggi(t+2)  Terendah(t+2)  \
# Tanggal                                    ...
# 2023-03-09        6691.61         6612.49  ...         6812.96        6758.00
# 2023-03-08        6612.49         6678.24  ...         6856.57        6801.19
# 2023-03-07        6678.24         6565.73  ...         6884.12        6804.48
# 2023-03-06        6565.73         6628.14  ...         6875.10        6841.86
# 2023-03-03        6628.14         6641.81  ...         6889.51        6833.19
# ...                   ...             ...  ...             ...            ...
# 2010-01-14        2578.41         2597.35  ...         2659.98        2623.77
# 2010-01-13        2597.86         2609.73  ...         2649.20        2615.61
# 2010-01-12        2610.34         2636.96  ...         2614.54        2583.85
# 2010-01-11        2638.38         2664.66  ...         2611.60        2570.27
# 2010-01-08        2667.27         2666.58  ...         2622.12        2587.71
#
#             Terakhir(t+3)  Pembukaan(t+3)  Tertinggi(t+3)  Terendah(t+3)  \
# Tanggal
# 2023-03-09        6807.00         6813.92         6856.57        6801.19
# 2023-03-08        6813.64         6857.42         6884.12        6804.48
# 2023-03-07        6857.42         6845.08         6875.10        6841.86
# 2023-03-06        6844.94         6843.10         6889.51        6833.19
# 2023-03-03        6843.24         6854.78         6890.35        6843.24
# ...                   ...             ...             ...            ...
# 2010-01-14        2632.20         2615.61         2649.20        2615.61
# 2010-01-13        2614.37         2586.79         2614.54        2583.85
# 2010-01-12        2586.89         2603.50         2611.60        2570.27
# 2010-01-11        2603.30         2605.48         2622.12        2587.71
# 2010-01-08        2605.28         2575.62         2606.07        2575.62
#
#             Terakhir(t+4)  Pembukaan(t+4)  Tertinggi(t+4)  Terendah(t+4)
# Tanggal
# 2023-03-09        6813.64         6857.42         6884.12        6804.48
# 2023-03-08        6857.42         6845.08         6875.10        6841.86
# 2023-03-07        6844.94         6843.10         6889.51        6833.19
# 2023-03-06        6843.24         6854.78         6890.35        6843.24
# 2023-03-03        6854.78         6856.58         6871.11        6819.87
# ...                   ...             ...             ...            ...
# 2010-01-14        2614.37         2586.79         2614.54        2583.85
# 2010-01-13        2586.89         2603.50         2611.60        2570.27
# 2010-01-12        2603.30         2605.48         2622.12        2587.71
# 2010-01-11        2605.28         2575.62         2606.07        2575.62
# 2010-01-08        2575.41         2533.95         2576.06        2532.90
#
# [3230 rows x 60 columns]

# %%
from sklearn.preprocessing import MinMaxScaler

# Inisialisasi MinMaxScaler
scaler = MinMaxScaler()

# Normalisasi data train
scaled_train_data = scaler.fit_transform(train_data)

# Konversi data yang telah dinormalisasi kembali ke dalam DataFrame
scaled_train_data = pd.DataFrame(scaled_train_data, columns=train_data.columns)

# %%
# Ambil kolom "Pembukaan" sebagai target
columns_terakhir =  ["Terakhir(t)"]+ [f"Terakhir(t+{i})" for i in range(1, 5)]  # Dari t sampai t+7

# Ambil kolom tersebut dari scaled_train_data sebagai target
y_train_scaled = scaled_train_data[columns_terakhir]

columns_to_drop = []

# Variabel yang ingin kamu drop (misalnya Pembukaan, Terakhir, Tertinggi, Terendah)
variables = ["Pembukaan", "Terakhir", "Tertinggi", "Terendah"]

# Loop untuk menambahkan kolom dari t hingga t+7 ke dalam list
for var in variables:
    # Tambahkan kolom untuk t
    columns_to_drop.append(f"{var}(t)")
    # Tambahkan kolom untuk t+1 hingga t+7
    for i in range(1, 5):
        columns_to_drop.append(f"{var}(t+{i})")

# Drop kolom yang sesuai dari scaled_train_data
X_train_scaled = scaled_train_data.drop(columns_to_drop, axis=1)

# %%
X_train_scaled.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3230 entries, 0 to 3229
# Data columns (total 40 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Terakhir(t-10)   3230 non-null   float64
#  1   Pembukaan(t-10)  3230 non-null   float64
#  2   Tertinggi(t-10)  3230 non-null   float64
#  3   Terendah(t-10)   3230 non-null   float64
#  4   Terakhir(t-9)    3230 non-null   float64
#  5   Pembukaan(t-9)   3230 non-null   float64
#  6   Tertinggi(t-9)   3230 non-null   float64
#  7   Terendah(t-9)    3230 non-null   float64
#  8   Terakhir(t-8)    3230 non-null   float64
#  9   Pembukaan(t-8)   3230 non-null   float64
#  10  Tertinggi(t-8)   3230 non-null   float64
#  11  Terendah(t-8)    3230 non-null   float64
#  12  Terakhir(t-7)    3230 non-null   float64
#  13  Pembukaan(t-7)   3230 non-null   float64
#  14  Tertinggi(t-7)   3230 non-null   float64
#  15  Terendah(t-7)    3230 non-null   float64
#  16  Terakhir(t-6)    3230 non-null   float64
#  17  Pembukaan(t-6)   3230 non-null   float64
#  18  Tertinggi(t-6)   3230 non-null   float64
#  19  Terendah(t-6)    3230 non-null   float64
#  20  Terakhir(t-5)    3230 non-null   float64
#  21  Pembukaan(t-5)   3230 non-null   float64
#  22  Tertinggi(t-5)   3230 non-null   float64
#  23  Terendah(t-5)    3230 non-null   float64
#  24  Terakhir(t-4)    3230 non-null   float64
#  25  Pembukaan(t-4)   3230 non-null   float64
#  26  Tertinggi(t-4)   3230 non-null   float64
#  27  Terendah(t-4)    3230 non-null   float64
#  28  Terakhir(t-3)    3230 non-null   float64
#  29  Pembukaan(t-3)   3230 non-null   float64
#  30  Tertinggi(t-3)   3230 non-null   float64
#  31  Terendah(t-3)    3230 non-null   float64
#  32  Terakhir(t-2)    3230 non-null   float64
#  33  Pembukaan(t-2)   3230 non-null   float64
#  34  Tertinggi(t-2)   3230 non-null   float64
#  35  Terendah(t-2)    3230 non-null   float64
#  36  Terakhir(t-1)    3230 non-null   float64
#  37  Pembukaan(t-1)   3230 non-null   float64
#  38  Tertinggi(t-1)   3230 non-null   float64
#  39  Terendah(t-1)    3230 non-null   float64
# dtypes: float64(40)
# memory usage: 1009.5 KB

# %%
y_train_scaled.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3230 entries, 0 to 3229
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Terakhir(t)    3230 non-null   float64
#  1   Terakhir(t+1)  3230 non-null   float64
#  2   Terakhir(t+2)  3230 non-null   float64
#  3   Terakhir(t+3)  3230 non-null   float64
#  4   Terakhir(t+4)  3230 non-null   float64
# dtypes: float64(5)
# memory usage: 126.3 KB

# %%
# Misalnya, Anda memiliki 3 langkah waktu dan 5 fitur
timesteps = 10
features = 4
X_train = []
for i in range(timesteps):
    X_train.append(X_train_scaled.iloc[:, i*features:(i+1)*features].values)

# Ubah list menjadi array numpy
X_train = np.array(X_train)
X_train = X_train.transpose(1, 0, 2)
# Bentuknya menjadi (jumlah_sampel, timestep, feature)
print(X_train.shape)
# Out:
# (3230, 10, 4)

# %%
from keras.layers import LSTM
from keras.layers import Bidirectional

model_lstm = Sequential()
model_lstm.add(Bidirectional(LSTM(128, activation='relu',return_sequences=True, input_shape=(X_train.shape[1], 4))))
model_lstm.add(Dropout(0.1))
model_lstm.add(LSTM(128,activation='relu', return_sequences=False))
model_lstm.add(Dense(128))
model_lstm.add(Dense(5))

# %%
early_stopping = EarlyStopping(monitor='loss', patience=20, verbose=1, restore_best_weights=True
200
# 101/101 [==============================] - 3s 27ms/step - loss: 11391.5566 - mse: 11391.5566
# Epoch 156/200
# 101/101 [==============================] - 3s 27ms/step - loss: 12454.2402 - mse: 12454.2402
# Epoch 157/200
# 101/101 [==============================] - 3s 28ms/step - loss: 13577.7705 - mse: 13577.7705
# Epoch 158/200
# 101/101 [==============================] - 3s 27ms/step - loss: 11660.0684 - mse: 11660.0684
# Epoch 159/200
# 101/101 [==============================] - 3s 28ms/step - loss: 11444.8789 - mse: 11444.8789
# Epoch 160/200
# 101/101 [==============================] - ETA: 0s - loss: 10531.9180 - mse: 10531.9180Restoring model weights from the end of the best epoch: 140.
# 101/101 [==============================] - 3s 27ms/step - loss: 10531.9180 - mse: 10531.9180
# Epoch 160: early stopping

# %%
y_pred = model_lstm.predict(X_train)
# Out:
# 101/101 [==============================] - 1s 8ms/step

# %%
y_pred.shape
# Out:
# (3230, 5)

# %%
y_pred.squeeze()
# Out:
# array([[6593.4517, 6603.36  , 6602.663 , 6588.991 , 6571.329 ],
#        [6607.264 , 6617.2173, 6616.5166, 6602.814 , 6585.1143],
#        [6604.286 , 6614.2407, 6613.5454, 6599.85  , 6582.1724],
#        ...,
#        [2572.7888, 2578.0806, 2578.6006, 2572.053 , 2566.0374],
#        [2573.8027, 2579.058 , 2579.5967, 2573.048 , 2567.0093],
#        [2572.572 , 2577.7856, 2578.3416, 2571.7979, 2565.7346]],
#       dtype=float32)

# %%
train_data['Terakhir(t)']
# Out:
# Tanggal
# 2023-03-09    6799.79
# 2023-03-08    6776.37
# 2023-03-07    6766.76
# 2023-03-06    6807.00
# 2023-03-03    6813.64
#                ...
# 2010-01-14    2645.18
# 2010-01-13    2632.87
# 2010-01-12    2659.55
# 2010-01-11    2632.20
# 2010-01-08    2614.37
# Name: Terakhir(t), Length: 3230, dtype: float64

# %%
y_true = train_data[["Terakhir(t)"] + [f"Terakhir(t+{i})" for i in range(1, 5)]].values

# %%
mse = np.mean((y_pred.squeeze() - y_true)**2)

# Menghitung Root Mean Squared Error (RMSE)
rmse = np.sqrt(mse)

print("MSE:", mse)
print("RMSE:", rmse)
# Out:
# MSE: 21631.85998418432
# RMSE: 147.07773449500885

# %%
y_pred_df = pd.DataFrame(y_pred, columns=["Terakhir(t)"] + [f"Terakhir(t+{i})" for i in range(1, 5)])

# %%
y_pred_df
# Out:
#       Terakhir(t)  Terakhir(t+1)  Terakhir(t+2)  Terakhir(t+3)  Terakhir(t+4)
# 0     6593.451660    6603.359863    6602.663086    6588.991211    6571.329102
# 1     6607.264160    6617.217285    6616.516602    6602.813965    6585.114258
# 2     6604.286133    6614.240723    6613.545410    6599.850098    6582.172363
# 3     6612.796387    6622.760254    6622.061523    6608.346191    6590.635742
# 4     6616.928711    6626.878418    6626.178711    6612.452637    6594.719727
# ...           ...            ...            ...            ...            ...
# 3225  2567.431885    2572.770508    2573.255127    2566.724365    2560.734619
# 3226  2565.585938    2570.895996    2571.400879    2564.867188    2558.881592
# 3227  2572.788818    2578.080566    2578.600586    2572.052979    2566.037354
# 3228  2573.802734    2579.058105    2579.596680    2573.048096    2567.009277
# 3229  2572.572021    2577.785645    2578.341553    2571.797852    2565.734619
#
# [3230 rows x 5 columns]

# %%
import matplotlib.pyplot as plt

first_row_values = y_pred_df.iloc[0, 1:5].values  # Mengambil kolom 1 hingga 9

# Mengonversi nilai menjadi list (opsional)
first_row_values_list = first_row_values.tolist()

# Plot hasil prediksi (y_pred) dan data aktual (train_data['Open(t)'])
plt.figure(figsize=(10, 6))
plt.plot(train_data.index[:100],y_pred_df['Terakhir(t)'][:100], label='Prediksi (y_pred)', color='red')
plt.plot(train_data.index[:100], train_data['Terakhir(t)'][:100], label='Data Aktual', color='blue')
plt.plot(train_data.index[:4], first_row_values_list, label='Forecast', color='green')
plt.plot(train_data.index[:4], train_data['Terakhir(t)'][:4], label='actual Forecast', color='yellow')
plt.xlabel('Tanggal')
plt.ylabel('Nilai Open')
plt.title('Prediksi vs Data Aktual')
plt.legend()
plt.show()

# %%
train_data['Terakhir(t)'][:9]
# Out:
# Tanggal
# 2023-03-20    6612.49
# 2023-03-17    6678.24
# 2023-03-16    6565.73
# 2023-03-15    6628.14
# 2023-03-14    6641.81
# 2023-03-13    6786.96
# 2023-03-10    6765.30
# 2023-03-09    6799.79
# 2023-03-08    6776.37
# Name: Terakhir(t), dtype: float64

# %%
scaled_val_data = scaler.transform(validation_data)

# Konversi data yang telah dinormalisasi kembali ke dalam DataFrame
scaled_val_data = pd.DataFrame(scaled_val_data, columns=validation_data.columns)

# %%
scaled_val_data
# Out:
#      Terakhir(t-3)  Pembukaan(t-3)  Tertinggi(t-3)  Terendah(t-3)  \
# 0         1.043358        1.057840        1.049399       1.050246
# 1         1.066931        1.048225        1.054145       1.055487
# 2         1.043348        1.073586        1.061738       1.051529
# 3         1.078246        1.081744        1.073540       1.079499
# 4         1.088075        1.083665        1.078893       1.081474
# ..             ...             ...             ...            ...
# 355       0.898636        0.894156        0.891938       0.902387
# 356       0.894116        0.894942        0.888294       0.899184
# 357       0.894873        0.901209        0.895881       0.901966
# 358       0.901170        0.884875        0.892378       0.893142
# 359       0.884833        0.874262        0.874606       0.882537
#
#      Terakhir(t-2)  Pembukaan(t-2)  Tertinggi(t-2)  Terendah(t-2)  \
# 0         1.066931        1.048225        1.054145       1.055487
# 1         1.043348        1.073586        1.061738       1.051529
# 2         1.078246        1.081744        1.073540       1.079499
# 3         1.088075        1.083665        1.078893       1.081474
# 4         1.087328        1.088775        1.078443       1.073302
# ..             ...             ...             ...            ...
# 355       0.894116        0.894942        0.888294       0.899184
# 356       0.894873        0.901209        0.895881       0.901966
# 357       0.901170        0.884875        0.892378       0.893142
# 358       0.884833        0.874262        0.874606       0.882537
# 359       0.874219        0.885271        0.876233       0.881674
#
#      Terakhir(t-1)  Pembukaan(t-1)  Tertinggi(t-1)  Terendah(t-1)  \
# 0         1.043348        1.073586        1.061738       1.051529
# 1         1.078246        1.081744        1.073540       1.079499
# 2         1.088075        1.083665        1.078893       1.081474
# 3         1.087328        1.088775        1.078443       1.073302
# 4         1.095090        1.094290        1.088604       1.090716
# ..             ...             ...             ...            ...
# 355       0.894873        0.901209        0.895881       0.901966
# 356       0.901170        0.884875        0.892378       0.893142
# 357       0.884833        0.874262        0.874606       0.882537
# 358       0.874219        0.885271        0.876233       0.881674
# 359       0.885230        0.871183        0.877112       0.879078
#
#      Terakhir(t)  Pembukaan(t)  Tertinggi(t)  Terendah(t)
# 0       1.078246      1.081744      1.073540     1.079499
# 1       1.088075      1.083665      1.078893     1.081474
# 2       1.087328      1.088775      1.078443     1.073302
# 3       1.095090      1.094290      1.088604     1.090716
# 4       1.094520      1.087815      1.081481     1.081936
# ..           ...           ...           ...          ...
# 355     0.901170      0.884875      0.892378     0.893142
# 356     0.884833      0.874262      0.874606     0.882537
# 357     0.874219      0.885271      0.876233     0.881674
# 358     0.885230      0.871183      0.877112     0.879078
# 359     0.870642      0.854349      0.859661     0.861962
#
# [360 rows x 16 columns]

# %%
y_val_scaled = scaled_val_data[["Terakhir(t)"]]  # Ambil kolom Open(t) sebagai target
X_val_scaled = scaled_val_data.drop(["Pembukaan(t)", "Terakhir(t)", "Tertinggi(t)", "Terendah(t)"], axis=1)

# %%
X_val = []
for i in range(timesteps):
    X_val.append(X_val_scaled.iloc[:, i*features:(i+1)*features].values)

# Ubah list menjadi array numpy
X_val = np.array(X_val)
X_val = X_val.transpose(1, 0, 2)
# Bentuknya menjadi (jumlah_sampel, timestep, feature)
print(X_val.shape)
# Out:
# (360, 3, 4)

# %%
y_val_pred = model_lstm.predict(X_val)
# Out:
# 12/12 [==============================] - 0s 3ms/step

# %%
y_val_pred.squeeze()
# Out:
# array([7586.0625, 7633.8374, 7660.7617, 7682.629 , 7715.123 , 7702.616 ,
#        7816.6743, 7828.5957, 7837.6416, 7818.9053, 7788.6104, 7768.0645,
#        7747.367 , 7708.86  , 7691.188 , 7663.7754, 7647.2246, 7577.6074,
#        7626.9585, 7633.6675, 7613.2124, 7629.805 , 7585.117 , 7561.8887,
#        7528.376 , 7495.5737, 7489.366 , 7505.5674, 7474.1543, 7431.248 ,
#        7418.8125, 7413.5586, 7379.2363, 7325.4014, 7274.424 , 7236.0605,
#        7220.9854, 7177.2393, 7128.2   , 7214.9004, 7262.8774, 7263.522 ,
#        7254.6035, 7269.727 , 7286.902 , 7264.1787, 7257.621 , 7278.673 ,
#        7305.8853, 7304.2266, 7293.034 , 7248.491 , 7254.258 , 7273.505 ,
#        7305.5767, 7314.4414, 7299.1074, 7283.828 , 7261.418 , 7252.4033,
#        7244.239 , 7226.8867, 7172.584 , 7160.4688, 7101.1763, 7031.7695,
#        6962.8984, 6915.3267, 6880.7295, 6879.54  , 6860.742 , 6781.482 ,
#        6758.418 , 6807.6465, 6866.7495, 6856.8193, 6896.7583, 6895.4717,
#        6967.5264, 6988.006 , 7087.825 , 7083.0244, 7055.619 , 7083.1787,
#        7111.037 , 7227.5225, 7231.75  , 7233.618 , 7212.7256, 7248.8213,
#        7301.6675, 7267.1875, 7230.3057, 7134.823 , 7117.4287, 7078.081 ,
#        7121.216 , 7133.1133, 7159.04  , 7146.1123, 7205.158 , 7195.234 ,
#        7196.9604, 7080.5605, 7134.9795, 7150.9414, 7137.38  , 7126.676 ,
#        7107.2695, 7121.161 , 7140.2134, 7193.406 , 7145.744 , 7216.5605,
#        7182.787 , 7213.784 , 7194.2944, 7251.1934, 7267.151 , 7326.1885,
#        7321.2837, 7322.04  , 7314.287 , 7342.6895, 7305.9233, 7311.4033,
#        7322.664 , 7366.1987, 7375.9434, 7391.155 , 7385.2686, 7343.798 ,
#        7275.3574, 7286.503 , 7298.1426, 7298.2793, 7306.615 , 7287.3125,
#        6816.9727, 6804.842 , 6843.275 , 6889.159 , 6929.912 , 6918.33  ,
#        6851.473 , 6809.318 , 6812.576 , 6791.534 , 6793.974 , 6803.415 ,
#        6771.1196, 6780.256 , 6805.699 , 6827.6   , 6822.9453, 6811.862 ,
#        6808.5684, 6833.245 , 6780.1797, 6728.8076, 6752.17  , 6706.212 ],
#       dtype=float32)

# %%
validation_data['Terakhir(t)']
# Out:
# Tanggal
# 2024-09-27    7696.92
# 2024-09-26    7744.52
# 2024-09-25    7740.90
# 2024-09-24    7778.49
# 2024-09-23    7775.73
#                ...
# 2023-03-29    6839.44
# 2023-03-28    6760.33
# 2023-03-27    6708.93
# 2023-03-24    6762.25
# 2023-03-21    6691.61
# Name: Terakhir(t), Length: 360, dtype: float64

# %%
import matplotlib.pyplot as plt

# Plot hasil prediksi (y_pred) dan data aktual (train_data['Open(t)'])
plt.figure(figsize=(10, 6))
plt.plot(validation_data.index[:30], y_val_pred.squeeze()[:30], label='Prediksi (y_pred)', color='red')
plt.plot(validation_data.index[:30], validation_data['Terakhir(t)'][:30], label='Data Aktual', color='blue')
plt.xlabel('Tanggal')
plt.ylabel('Nilai Open')
plt.title('Prediksi vs Data Aktual')
plt.legend()
plt.show()

# %%
mse = np.mean((y_val_pred.squeeze() - validation_data['Terakhir(t)'])**2)

# Menghitung Root Mean Squared Error (RMSE)
rmse = np.sqrt(mse)

print("MSE:", mse)
print("RMSE:", rmse)
# Out:
# MSE: 768.4215078199778
# RMSE: 27.72041680458607

# %% [markdown]
# # Return

# %%
data['Return'] = data['Close'].pct_change()
data = data.dropna()  # Menghapus NaN hasil dari perhitungan pct_change

# %%
data.columns[5]
# Out:
# 'Return'

# %%
def time_series_to_supervised(data, n_in=1, n_out=1, dropnan=True, var_names=None):
    """
    Mengubah data time series menjadi data supervised learning.

    Argumen:
    data: DataFrame atau Series, dataset time series yang akan diubah.
    n_in: int, jumlah timestep mundur sebagai input (X).
    n_out: int, jumlah timestep maju sebagai output (y).
    dropnan: bool, apakah akan menghapus baris dengan nilai NaN.
    var_names: list of str, nama variabel untuk setiap kolom.

    Returns:
    DataFrame yang sudah diubah menjadi format supervised learning.
    """
    if isinstance(data, pd.Series):
        data = data.to_frame()
        
    n_vars = data.shape[1]
    df = pd.DataFrame(data)
    cols, names = [], []
    
    # Input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        if var_names is None:
            names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
        else:
            names += [(var_names[j] + '(t-%d)' % i) for j in range(n_vars)]
    
    # Output sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            if var_names is None:
                names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
            else:
                names += [(var_names[j] + '(t)') for j in range(n_vars)]
        else:
            if var_names is None:
                names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
            else:
                names += [(var_names[j] + '(t+%d)' % i) for j in range(n_vars)]
    
    # Concatenate semua kolom
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    
    # Hapus baris dengan nilai NaN
    if dropnan:
        agg.dropna(inplace=True)
    
    return agg

# %%
data_supervised_return = time_series_to_supervised(data['Return'], n_in=5, n_out=1, var_names=['Return'])

# %%
train_data_return = data_supervised_return[:lengh_train]
validation_data_return = data_supervised_return[lengh_train:]

# %%
scaled_train_data_return = scaler.fit_transform(train_data_return)
scaled_train_data_return = pd.DataFrame(scaled_train_data_return, columns=train_data_return.columns)
print(scaled_train_data_return.columns)
# Out:
# Index(['Return(t-5)', 'Return(t-4)', 'Return(t-3)', 'Return(t-2)',
#        'Return(t-1)', 'Return(t)'],
#       dtype='object')

# %%
scaled_train_data_return = scaler.fit_transform(train_data_return)
scaled_train_data_return = pd.DataFrame(scaled_train_data_return, columns=train_data_return.columns)

y_train_return_scaled = scaled_train_data_return[["Return(t)"]]
X_train_return_scaled = scaled_train_data_return.drop(["Return(t)"], axis=1)

# %%
timesteps =5
features = 1
X_train = []
for i in range(timesteps):
    X_train.append(X_train_return_scaled.iloc[:, i*features:(i+1)*features].values)

X_train = np.array(X_train).transpose(1, 0, 2)
print(X_train.shape)  # Output seharusnya berbentuk (jumlah_sampel, timestep, features)
# Out:
# (255, 5, 1)

# %%
model_lstm = Sequential()

# Adding layers
model_lstm.add(Bidirectional(LSTM(64, activation='relu', return_sequences=True), input_shape=(X_train.shape[1], X_train.shape[2])))
model_lstm.add(Dropout(0.1))
model_lstm.add(LSTM(64, activation='relu', return_sequences=False))
model_lstm.add(Dense(64))
model_lstm.add(Dense(1))

# Compile the model
model_lstm.compile(optimizer='adam', loss='mse', metrics=['mse'])

# Early stopping to avoid overfitting
early_stopping = EarlyStopping(monitor='loss', patience=20, verbose=1, restore_best_weights=True)

# Fit the model
hist = model_lstm.fit(X_train, train_data_return['Return(t)'], 
                      epochs=200, 
                      batch_size=32,
                      callbacks=[early_stopping])

# Make predictions
y_pred = model_lstm.predict(X_train)
# Out:
# Epoch 1/200
# 8/8 [==============================] - 6s 9ms/step - loss: 2.9349e-04 - mse: 2.9349e-04
# Epoch 2/200
# 8/8 [==============================] - 0s 15ms/step - loss: 1.1305e-04 - mse: 1.1305e-04
# Epoch 3/200
# 8/8 [==============================] - 0s 10ms/step - loss: 6.8424e-05 - mse: 6.8424e-05
# Epoch 4/200
# 8/8 [==============================] - 0s 8ms/step - loss: 5.0882e-05 - mse: 5.0882e-05
# Epoch 5/200
# 8/8 [==============================] - 0s 7ms/step - loss: 4.4575e-05 - mse: 4.4575e-05
# Epoch 6/200
# 8/8 [==============================] - 0s 7ms/step - loss: 4.2782e-05 - mse: 4.2782e-05
# Epoch 7/200
# 8/8 [==============================] - 0s 8ms/step - loss: 3.9735e-05 - mse: 3.9735e-05
# Epoch 8/200
# 8/8 [==============================] - 0s 8ms/step - loss: 3.9514e-05 - mse: 3.9514e-05
# Epoch 9/200
# 8/8 [==============================] - 0s 8ms/step - loss: 4.0431e-05 - mse: 4.0431e-05
# Epoch 10/200
# 8/8 [==============================] - 0s 7ms/step - loss: 3.9627e-05 - mse: 3.9627e-05
# Epoch 11/200
# 8/8 [==============================] - 0s 7ms/step - loss: 4.0703e-05 - mse: 4.0703e-05
# Epoch 12/200
# 8/8 [==============================] - 0s 7ms/step - loss: 3.9776e-05 - mse: 3.9776e-05
# Epoch 13/200
# 8/8 [==============================] - 0s 7ms/step - loss: 3.9444e-05 - mse: 3.9444e-05
# Epoch 14/200
# 8/8 [==============================] - 0s 7ms/step - loss: 3.9423e-05 - mse: 3.9423e-05
# Epoch 15/200
# 8/8 [==============================] - 0s 7ms/step - loss: 4.0656e-05 - mse: 4.0656e-05
# Epoch 16/200
# 8/8 [==============================] - 0s 7ms/step - loss: 4.0638e-05 - mse: 4.0638e-05
# Epoch 17/200
# 8/8 [==============================] - 0s 7ms/step - loss: 3.8379e-05 - mse: 3.8379e-05
# Epoch 18/200
# 8/8 [==============================] - 0s 7ms/step - loss: 3.8781e-05 - mse: 3.8781e-05
# Epoch 19/200
# 8/8 [==============================] - 0s 7ms/step - loss: 3.8585e-05 - mse: 3.8585e-05
# Epoch 20/200
# 8/8 [==============================] - 0s 7ms/step - loss: 3.9890e-05 - mse: 3.9890e-05
# Epoch 21/200
# 8/8 [==============================] - 0s 7ms/step - loss: 3.9729e-05 - mse: 3.9729e-05
# Epoch 22/200
# 8/8 [==============================] - 0s 7ms/step - loss: 3.9816e-05 - mse: 3.9816e-05
# Epoch 23/200
# 8/8 [==============================] - 0s 7ms/step - loss: 4.2042e-05 - mse: 4.2042e-05
# Epoch 24/200
# 8/8 [==============================] - 0s 8ms/step - loss: 4.5988e-05 - mse: 4.5988e-05
# Epoch 25/200
# 8/8 [==============================] - 0s 8ms/step - loss: 4.7728e-05 - mse: 4.7728e-05
# Epoch 26/200
# 8/8 [==============================] - 0s 9ms/step - loss: 4.4768e-05 - mse: 4.4768e-05
# Epoch 27/200
# 8/8 [==============================] - 0s 8ms/step - loss: 4.2358e-05 - mse: 4.2358e-05
# Epoch 28/200
# 8/8 [==============================] - 0s 8ms/step - loss: 3.9439e-05 - mse: 3.9439e-05
# Epoch 29/200
# 8/8 [==============================] - 0s 8ms/step - loss: 3.9388e-05 - mse: 3.9388e-05
# Epoch 30/200
# 8/8 [==============================] - 0s 7ms/step - loss: 4.0938e-05 - mse: 4.0938e-05
# Epoch 31/200
# 8/8 [==============================] - 0s 7ms/step - loss: 4.1120e-05 - mse: 4.1120e-05
# Epoch 32/200
# 8/8 [==============================] - 0s 7ms/step - loss: 3.8808e-05 - mse: 3.8808e-05
# Epoch 33/200
# 8/8 [==============================] - 0s 7ms/step - loss: 3.9558e-05 - mse: 3.9558e-05
# Epoch 34/200
# 8/8 [==============================] - 0s 7ms/step - loss: 3.9463e-05 - mse: 3.9463e-05
# Epoch 35/200
# 8/8 [==============================] - 0s 8ms/step - loss: 4.2487e-05 - mse: 4.2487e-05
# Epoch 36/200
# 8/8 [==============================] - 0s 8ms/step - loss: 4.0662e-05 - mse: 4.0662e-05
# Epoch 37/200
# 8/8 [==============================] - 0s 7ms/step - loss: 3.8134e-05 - mse: 3.8134e-05
# Epoch 38/200
# 8/8 [==============================] - 0s 6ms/step - loss: 3.9087e-05 - mse: 3.9087e-05
# Epoch 39/200
# 8/8 [==============================] - 0s 7ms/step - loss: 3.8473e-05 - mse: 3.8473e-05
# Epoch 40/200
# 8/8 [==============================] - 0s 7ms/step - loss: 3.9982e-05 - mse: 3.9982e-05
# Epoch 41/200
# 8/8 [==============================] - 0s 9ms/step - loss: 3.9722e-05 - mse: 3.9722e-05
# Epoch 42/200
# 8/8 [==============================] - 0s 7ms/step - loss: 3.9906e-05 - mse: 3.9906e-05
# Epoch 43/200
# 8/8 [==============================] - 0s 7ms/step - loss: 3.9029e-05 - mse: 3.9029e-05
# Epoch 44/200
# 8/8 [==============================] - 0s 7ms/step - loss: 3.8565e-05 - mse: 3.8565e-05
# Epoch 45/200
# 8/8 [==============================] - 0s 14ms/step - loss: 3.9932e-05 - mse: 3.9932e-05
# Epoch 46/200
# 8/8 [==============================] - 0s 8ms/step - loss: 4.1102e-05 - mse: 4.1102e-05
# Epoch 47/200
# 8/8 [==============================] - 0s 8ms/step - loss: 3.7915e-05 - mse: 3.7915e-05
# Epoch 48/200
# 8/8 [==============================] - 0s 7ms/step - loss: 4.0167e-05 - mse: 4.0167e-05
# Epoch 49/200
# 8/8 [==============================] - 0s 7ms/step - loss: 3.8381e-05 - mse: 3.8381e-05
# Epoch 50/200
# 8/8 [==============================] - 0s 7ms/step - loss: 3.9473e-05 - mse: 3.9473e-05
# Epoch 51/200
# 8/8 [==============================] - 0s 7ms/step - loss: 3.9086e-05 - mse: 3.9086e-05
# Epoch 52/200
# 8/8 [==============================] - 0s 7ms/step - loss: 3.8684e-05 - mse: 3.8684e-05
# Epoch 53/200
# 8/8 [==============================] - 0s 7ms/step - loss: 3.7683e-05 - mse: 3.7683e-05
# Epoch 54/200
# 8/8 [==============================] - 0s 7ms/step - loss: 4.4953e-05 - mse: 4.4953e-05
# Epoch 55/200
# 8/8 [==============================] - 0s 7ms/step - loss: 3.9801e-05 - mse: 3.9801e-05
# Epoch 56/200
# 8/8 [==============================] - 0s 7ms/step - loss: 3.8043e-05 - mse: 3.8043e-05
# Epoch 57/200
# 8/8 [==============================] - 0s 7ms/step - loss: 4.0613e-05 - mse: 4.0613e-05
# Epoch 58/200
# 8/8 [==============================] - 0s 7ms/step - loss: 3.7025e-05 - mse: 3.7025e-05
# Epoch 59/200
# 8/8 [==============================] - 0s 7ms/step - loss: 3.8736e-05 - mse: 3.8736e-05
# Epoch 60/200
# 8/8 [==============================] - 0s 7ms/step - loss: 3.7865e-05 - mse: 3.7865e-05
# Epoch 61/200
# 8/8 [==============================] - 0s 7ms/step - loss: 4.4141e-05 - mse: 4.4141e-05
# Epoch 62/200
# 8/8 [==============================] - 0s 7ms/step - loss: 4.0807e-05 - mse: 4.0807e-05
# Epoch 63/200
# 8/8 [==============================] - 0s 7ms/step - loss: 3.9583e-05 - mse: 3.9583e-05
# Epoch 64/200
# 8/8 [==============================] - 0s 7ms/step - loss: 3.9766e-05 - mse: 3.9766e-05
# Epoch 65/200
# 8/8 [==============================] - 0s 7ms/step - loss: 3.8868e-05 - mse: 3.8868e-05
# Epoch 66/200
# 8/8 [==============================] - 0s 9ms/step - loss: 4.1639e-05 - mse: 4.1639e-05
# Epoch 67/200
# 8/8 [==============================] - 0s 9ms/step - loss: 3.8629e-05 - mse: 3.8629e-05
# Epoch 68/200
# 8/8 [==============================] - 0s 8ms/step - loss: 4.1274e-05 - mse: 4.1274e-05
# Epoch 69/200
# 8/8 [==============================] - 0s 7ms/step - loss: 4.2995e-05 - mse: 4.2995e-05
# Epoch 70/200
# 8/8 [==============================] - 0s 7ms/step - loss: 4.0118e-05 - mse: 4.0118e-05
# Epoch 71/200
# 8/8 [==============================] - 0s 8ms/step - loss: 3.7565e-05 - mse: 3.7565e-05
# Epoch 72/200
# 8/8 [==============================] - 0s 10ms/step - loss: 3.8611e-05 - mse: 3.8611e-05
# Epoch 73/200
# 8/8 [==============================] - 0s 8ms/step - loss: 4.0135e-05 - mse: 4.0135e-05
# Epoch 74/200
# 8/8 [==============================] - 0s 8ms/step - loss: 4.2684e-05 - mse: 4.2684e-05
# Epoch 75/200
# 8/8 [==============================] - 0s 8ms/step - loss: 4.4811e-05 - mse: 4.4811e-05
# Epoch 76/200
# 8/8 [==============================] - 0s 7ms/step - loss: 4.9223e-05 - mse: 4.9223e-05
# Epoch 77/200
# 8/8 [==============================] - 0s 8ms/step - loss: 4.5259e-05 - mse: 4.5259e-05
# Epoch 78/200
# 8/8 [==============================] - ETA: 0s - loss: 4.1361e-05 - mse: 4.1361e-05Restoring model weights from the end of the best epoch: 58.
# 8/8 [==============================] - 0s 9ms/step - loss: 4.1361e-05 - mse: 4.1361e-05
# Epoch 78: early stopping
# 8/8 [==============================] - 1s 3ms/step

# %%
# Calculate MSE and RMSE
mse = np.mean((y_pred.squeeze() - train_data_return['Return(t)'].values.squeeze())**2)
rmse = np.sqrt(mse)

print("MSE:", mse)
print("RMSE:", rmse)
# Out:
# MSE: 4.020205125247256e-05
# RMSE: 0.0063405087534418375

# %%
# Plot the results
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(train_data_return.index, y_pred.squeeze(), label='Prediksi (y_pred)', color='red')
plt.plot(train_data_return.index, train_data_return['Return(t)'], label='Data Aktual', color='blue')
plt.xlabel('Tanggal')
plt.ylabel('Nilai Open')
plt.title('Prediksi vs Data Aktual')
plt.legend()
plt.show()
