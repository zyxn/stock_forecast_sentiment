# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import xgboost as xgb
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("../data/external/ihsg 14-12-22 till 22-04-24.csv")
data.head(3)
# Out:
#          Date         Open         High          Low        Close  \
# 0  2022-12-14  6810.355957  6854.098145  6774.131836  6801.749023
# 1  2022-12-15  6801.789063  6801.837891  6740.955078  6751.859863
# 2  2022-12-16  6751.859863  6812.192871  6693.765137  6812.192871
#
#      Adj Close     Volume
# 0  6801.749023  215430000
# 1  6751.859863  145093400
# 2  6812.192871  156126900

# %%
lengh_data = len(data)
split_ratio = 0.8
lengh_train = round(lengh_data * split_ratio)
lengh_validation = lengh_data -lengh_train

# %%
data = data.drop(["Volume"],axis=1)
data['Date'] = pd.to_datetime(data['Date'])
data = data.set_index("Date")

#hai widha

# %%
def time_series_to_supervised(data, n_in=1, n_out=1, dropnan=True, var_names=None):
    """
    Mengubah data time series menjadi data supervised learning.

    Argumen:
    data: DataFrame, dataset time series yang akan diubah.
    n_in: int, jumlah timestep mundur sebagai input (X).
    n_out: int, jumlah timestep maju sebagai output (y).
    dropnan: bool, apakah akan menghapus baris dengan nilai NaN.
    var_names: list of str, nama variabel untuk setiap kolom.

    Returns:
    DataFrame yang sudah diubah menjadi format supervised learning.
    """
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = [], []
    
    # Input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        if var_names is None:
            names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
        else:
            names += [(var_names[j] + '(t-%d)' % i) for j in range(n_vars)]
    
    # Output sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            if var_names is None:
                names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
            else:
                names += [(var_names[j] + '(t)') for j in range(n_vars)]
        else:
            if var_names is None:
                names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
            else:
                names += [(var_names[j] + '(t+%d)' % i) for j in range(n_vars)]
    
    # Concatenate semua kolom
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    
    # Hapus baris dengan nilai NaN
    if dropnan:
        agg.dropna(inplace=True)
    
    return agg

# Contoh penggunaan:
# Misalkan 'data' adalah DataFrame yang berisi data time series
# dengan tiga fitur, dan kita ingin menggunakan 3 timestep mundur sebagai input
# dan 1 timestep maju sebagai output, dan nama variabel untuk setiap fitur adalah
# 'A', 'B', dan 'C'

var_names = data.columns
data_supervised = time_series_to_supervised(data, n_in=15, n_out=1, var_names=var_names)

# %%
train_data = data_supervised[:lengh_train]
validation_data = data_supervised[lengh_train:]

# %%
from sklearn.preprocessing import MinMaxScaler

# Inisialisasi MinMaxScaler
scaler = MinMaxScaler()

# Normalisasi data train
scaled_train_data = scaler.fit_transform(train_data)

# Konversi data yang telah dinormalisasi kembali ke dalam DataFrame
scaled_train_data = pd.DataFrame(scaled_train_data, columns=train_data.columns)

# %%
y_train_scaled = scaled_train_data[["Open(t)"]]  # Ambil kolom Open(t) sebagai target
X_train_scaled = scaled_train_data.drop(["Open(t)", "Close(t)", "High(t)", "Low(t)", "Adj Close(t)"], axis=1)

# %%
X_train_scaled.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 255 entries, 0 to 254
# Data columns (total 75 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Open(t-15)       255 non-null    float64
#  1   High(t-15)       255 non-null    float64
#  2   Low(t-15)        255 non-null    float64
#  3   Close(t-15)      255 non-null    float64
#  4   Adj Close(t-15)  255 non-null    float64
#  5   Open(t-14)       255 non-null    float64
#  6   High(t-14)       255 non-null    float64
#  7   Low(t-14)        255 non-null    float64
#  8   Close(t-14)      255 non-null    float64
#  9   Adj Close(t-14)  255 non-null    float64
#  10  Open(t-13)       255 non-null    float64
#  11  High(t-13)       255 non-null    float64
#  12  Low(t-13)        255 non-null    float64
#  13  Close(t-13)      255 non-null    float64
#  14  Adj Close(t-13)  255 non-null    float64
#  15  Open(t-12)       255 non-null    float64
#  16  High(t-12)       255 non-null    float64
#  17  Low(t-12)        255 non-null    float64
#  18  Close(t-12)      255 non-null    float64
#  19  Adj Close(t-12)  255 non-null    float64
#  20  Open(t-11)       255 non-null    float64
#  21  High(t-11)       255 non-null    float64
#  22  Low(t-11)        255 non-null    float64
#  23  Close(t-11)      255 non-null    float64
#  24  Adj Close(t-11)  255 non-null    float64
#  25  Open(t-10)       255 non-null    float64
#  26  High(t-10)       255 non-null    float64
#  27  Low(t-10)        255 non-null    float64
#  28  Close(t-10)      255 non-null    float64
#  29  Adj Close(t-10)  255 non-null    float64
#  30  Open(t-9)        255 non-null    float64
#  31  High(t-9)        255 non-null    float64
#  32  Low(t-9)         255 non-null    float64
#  33  Close(t-9)       255 non-null    float64
#  34  Adj Close(t-9)   255 non-null    float64
#  35  Open(t-8)        255 non-null    float64
#  36  High(t-8)        255 non-null    float64
#  37  Low(t-8)         255 non-null    float64
#  38  Close(t-8)       255 non-null    float64
#  39  Adj Close(t-8)   255 non-null    float64
#  40  Open(t-7)        255 non-null    float64
#  41  High(t-7)        255 non-null    float64
#  42  Low(t-7)         255 non-null    float64
#  43  Close(t-7)       255 non-null    float64
#  44  Adj Close(t-7)   255 non-null    float64
#  45  Open(t-6)        255 non-null    float64
#  46  High(t-6)        255 non-null    float64
#  47  Low(t-6)         255 non-null    float64
#  48  Close(t-6)       255 non-null    float64
#  49  Adj Close(t-6)   255 non-null    float64
#  50  Open(t-5)        255 non-null    float64
#  51  High(t-5)        255 non-null    float64
#  52  Low(t-5)         255 non-null    float64
#  53  Close(t-5)       255 non-null    float64
#  54  Adj Close(t-5)   255 non-null    float64
#  55  Open(t-4)        255 non-null    float64
#  56  High(t-4)        255 non-null    float64
#  57  Low(t-4)         255 non-null    float64
#  58  Close(t-4)       255 non-null    float64
#  59  Adj Close(t-4)   255 non-null    float64
#  60  Open(t-3)        255 non-null    float64
#  61  High(t-3)        255 non-null    float64
#  62  Low(t-3)         255 non-null    float64
#  63  Close(t-3)       255 non-null    float64
#  64  Adj Close(t-3)   255 non-null    float64
#  65  Open(t-2)        255 non-null    float64
#  66  High(t-2)        255 non-null    float64
#  67  Low(t-2)         255 non-null    float64
#  68  Close(t-2)       255 non-null    float64
#  69  Adj Close(t-2)   255 non-null    float64
#  70  Open(t-1)        255 non-null    float64
#  71  High(t-1)        255 non-null    float64
#  72  Low(t-1)         255 non-null    float64
#  73  Close(t-1)       255 non-null    float64
#  74  Adj Close(t-1)   255 non-null    float64
# dtypes: float64(75)
# memory usage: 149.5 KB

# %%
y_train_scaled.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 255 entries, 0 to 254
# Data columns (total 1 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Open(t)  255 non-null    float64
# dtypes: float64(1)
# memory usage: 2.1 KB

# %%
X_train_scaled
# Out:
#      Open(t-15)  High(t-15)  Low(t-15)  Close(t-15)  Adj Close(t-15)  \
# 0      0.326005    0.309047   0.313632     0.297243         0.297243
# 1      0.314588    0.239222   0.268654     0.234413         0.234413
# 2      0.248050    0.253057   0.204677     0.310395         0.310395
# 3      0.328401    0.273930   0.286458     0.269472         0.269472
# 4      0.285149    0.226348   0.233527     0.255137         0.255137
# ..          ...         ...        ...          ...              ...
# 250    0.933980    0.915785   0.975389     0.929632         0.929632
# 251    0.988009    0.917892   0.971903     0.890475         0.890475
# 252    0.936418    0.936338   0.952765     0.954441         0.954441
# 253    1.000000    0.934055   0.993854     0.898402         0.898402
# 254    0.965292    1.000000   1.000000     1.000000         1.000000
#
#      Open(t-14)  High(t-14)  Low(t-14)  Close(t-14)  Adj Close(t-14)  ...  \
# 0      0.291232    0.229312   0.245304     0.234413         0.234413  ...
# 1      0.229634    0.242574   0.186888     0.310395         0.310395  ...
# 2      0.304019    0.262583   0.261561     0.269472         0.269472  ...
# 3      0.263978    0.216972   0.213230     0.255137         0.255137  ...
# 4      0.249936    0.253423   0.273456     0.321063         0.321063  ...
# ..          ...         ...        ...          ...              ...  ...
# 250    0.914655    0.879869   0.887430     0.890475         0.890475  ...
# 251    0.866894    0.897551   0.869956     0.954441         0.954441  ...
# 252    0.925756    0.895362   0.907474     0.898402         0.898402  ...
# 253    0.893625    0.958576   0.913085     1.000000         1.000000  ...
# 254    1.000000    1.000000   1.000000     0.988484         0.988484  ...
#
#      Open(t-2)  High(t-2)  Low(t-2)  Close(t-2)  Adj Close(t-2)  Open(t-1)  \
# 0     0.351624   0.299820  0.347459    0.359248        0.359248   0.351924
# 1     0.351924   0.365283  0.366145    0.406821        0.406821   0.398577
# 2     0.398577   0.355807  0.334783    0.311713        0.311713   0.305408
# 3     0.305408   0.244148  0.098034    0.110968        0.110968   0.108606
# 4     0.108606   0.109944  0.069141    0.149653        0.149653   0.146602
# ..         ...        ...       ...         ...             ...        ...
# 250   0.841747   0.806449  0.767111    0.799595        0.799595   0.781092
# 251   0.781092   0.825178  0.795451    0.865502        0.865502   0.870526
# 252   0.870526   0.839137  0.777410    0.833305        0.833305   0.823437
# 253   0.823437   0.800649  0.807300    0.859156        0.859156   0.822626
# 254   0.822626   0.811280  0.815815    0.869610        0.869610   0.851315
#
#      High(t-1)  Low(t-1)  Close(t-1)  Adj Close(t-1)
# 0     0.365283  0.366145    0.406821        0.406821
# 1     0.355807  0.334783    0.311713        0.311713
# 2     0.244148  0.098034    0.110968        0.110968
# 3     0.109944  0.069141    0.149653        0.149653
# 4     0.133418  0.118657    0.154322        0.154322
# ..         ...       ...         ...             ...
# 250   0.825178  0.795451    0.865502        0.865502
# 251   0.839137  0.777410    0.833305        0.833305
# 252   0.800649  0.807300    0.859156        0.859156
# 253   0.811280  0.815815    0.869610        0.869610
# 254   0.831426  0.776782    0.833836        0.833836
#
# [255 rows x 75 columns]

# %%
model_xgb = xgb.XGBRegressor(objective='reg:squarederror', reg_lambda=0.002, gamma=1.004, max_depth=1, n_estimators=699, learning_rate=0.01, random_state=42, booster='gblinear')
model_xgb.fit(X_train_scaled,train_data["Open(t)"])
# Out:
# c:\Users\rizki\anaconda3\lib\site-packages\xgboost\core.py:160: UserWarning: [16:27:50] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0b3782d1791676daf-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "gamma", "max_depth" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# XGBRegressor(base_score=None, booster='gblinear', callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=1.004, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.01, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=1, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=699, n_jobs=None,
#              num_parallel_tree=None, random_state=42, ...)

# %%
y_pred = model_xgb.predict(X_train_scaled)

# %%
mse = np.mean((y_pred - train_data['Open(t)'])**2)

# Menghitung Root Mean Squared Error (RMSE)
rmse = np.sqrt(mse)

print("MSE:", mse)
print("RMSE:", rmse)
# Out:
# MSE: 2016.3938267989329
# RMSE: 44.904274037099555

# %%
import matplotlib.pyplot as plt

# Plot hasil prediksi (y_pred) dan data aktual (train_data['Open(t)'])
plt.figure(figsize=(10, 6))
plt.plot(train_data.index, y_pred.squeeze(), label='Prediksi (y_pred)', color='red')
plt.plot(train_data.index, train_data['Open(t)'], label='Data Aktual', color='blue')
plt.xlabel('Tanggal')
plt.ylabel('Nilai Open')
plt.title('Prediksi vs Data Aktual')
plt.legend()
plt.show
# 48   0.072375   0.048197  0.211858    0.118930        0.118930  0.002836
#
#      High(t)    Low(t)  Close(t)  Adj Close(t)
# 0   0.080254  0.176720  0.143848      0.143848
# 1   0.115435  0.221554  0.201903      0.201903
# 2   0.228876  0.273767  0.303178      0.303178
# 3   0.338601  0.439673  0.348626      0.348626
# 4   0.341834  0.437005  0.330577      0.330577
# 5   0.310688  0.405140  0.437772      0.437772
# 6   0.359602  0.421480  0.321673      0.321673
# 7   0.404487  0.494467  0.462694      0.462694
# 8   0.458811  0.531873  0.427271      0.427271
# 9   0.526029  0.601745  0.607957      0.607957
# 10  0.511421  0.454240  0.353830      0.353830
# 11  0.716282  0.737133  0.624177      0.624177
# 12  0.731904  0.783229  0.717426      0.717426
# 13  0.633415  0.678267  0.605163      0.605163
# 14  0.679288  0.768094  0.766722      0.766722
# 15  0.732901  0.703935  0.756375      0.756375
# 16  0.716535  0.801891  0.729251      0.729251
# 17  0.634803  0.634881  0.600519      0.600519
# 18  0.490819  0.607293  0.567941      0.567941
# 19  0.483752  0.615275  0.572258      0.572258
# 20  0.598202  0.711209  0.697459      0.697459
# 21  0.627556  0.711445  0.661258      0.661258
# 22  0.606439  0.656786  0.649109      0.649109
# 23  0.597070  0.628363  0.547495      0.547495
# 24  0.523755  0.568100  0.462844      0.462844
# 25  0.605688  0.596736  0.700824      0.700824
# 26  0.784016  0.837824  0.828464      0.828464
# 27  0.878494  0.955438  0.851422      0.851422
# 28  0.958986  1.000000  0.965006      0.965006
# 29  1.000000  0.968063  1.000000      1.000000
# 30  0.878193  0.763983  0.695776      0.695776
# 31  0.693488  0.744044  0.621773      0.621773
# 32  0.703010  0.781254  0.720898      0.720898
# 33  0.645254  0.728331  0.704660      0.704660
# 34  0.814691  0.844252  0.725542      0.725542
# 35  0.666643  0.793215  0.759643      0.759643
# 36  0.754885  0.788980  0.839435      0.839435
# 37  0.735977  0.827019  0.804476      0.804476
# 38  0.747342  0.721158  0.643862      0.643862
# 39  0.547942  0.586692  0.582362      0.582362
# 40  0.490374  0.284588  0.340303      0.340303
# 41  0.304931  0.330892  0.432566      0.432566
# 42  0.270952  0.344386  0.229849      0.229849
# 43  0.360593  0.364315  0.482899      0.482899
# 44  0.502698  0.570728  0.576781      0.576781
# 45  0.148650  0.085348  0.223961      0.223961
# 46  0.296589  0.265974  0.125792      0.125792
# 47  0.124583  0.279125  0.229762      0.229762
# 48  0.000000  0.000000  0.000000      0.000000
#
# [49 rows x 80 columns]

# %%
y_val_scaled = scaled_val_data[["Open(t)"]]  # Ambil kolom Open(t) sebagai target
X_val_scaled = scaled_val_data.drop(["Open(t)", "Close(t)", "High(t)", "Low(t)", "Adj Close(t)"], axis=1)

# %%
y_val_pred = model_xgb.predict(X_val_scaled)

# %%
mse = np.mean((y_val_pred - validation_data['Open(t)'])**2)

# Menghitung Root Mean Squared Error (RMSE)
rmse = np.sqrt(mse)

print("MSE:", mse)
print("RMSE:", rmse)
# Out:
# MSE: 93263.77137092403
# RMSE: 305.39117762457386

# %%
import matplotlib.pyplot as plt

# Plot hasil prediksi (y_pred) dan data aktual (train_data['Open(t)'])
plt.figure(figsize=(10, 6))
plt.plot(validation_data.index, y_val_pred, label='Prediksi (y_pred)', color='red')
plt.plot(validation_data.index, validation_data['Open(t)'], label='Data Aktual', color='blue')
plt.xlabel('Tanggal')
plt.ylabel('Nilai Open')
plt.title('Prediksi vs Data Aktual')
plt.legend()
plt.show()
